# %% [markdown]
# <a href="https://colab.research.google.com/github/MehrabHussain47/Problem-Solving/blob/master/_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Question
#
# <b>Create a class named 'Student' with the variable 'name' and 'roll_no'. And write a Display method to display the name and roll_no. Assign the value of roll_no as '2' and that of name as "John" by creating an object of the class Student.</b>

# %%
class Student:
  def __init__(self, name, roll_no):
    self.name = name
    self.roll_no = roll_no

  def Display(self):
    print(f"Name: {self.name}")
    print(f"Roll No: {self.roll_no}")

s1 = Student("John",2)
s1.Display()
# Out:
# Name: John
# Roll No: 2
