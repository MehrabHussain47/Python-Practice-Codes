# %% [markdown]
# <a href="https://colab.research.google.com/github/MehrabHussain47/Problem-Solving/blob/master/_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)
#
# # Above data stored in a Dataframe named df . Write the code for one hot encoding of Car Model.

# %%
import pandas as pd

# %%
data = {
    'Car Model': ['BMW X5', 'BMW X5', 'BMW X5', 'BMW X5', 'BMW X5',
                  'Audi A5', 'Audi A5', 'Audi A5', 'Audi A5',
                  'Mercedez Benz C class', 'Mercedez Benz C class',
                  'Mercedez Benz C class', 'Mercedez Benz C class'],
    'Mileage': [69000, 35000, 57000, 22500, 46000,
                59000, 52000, 72000, 91000,
                67000, 83000, 79000, 59000],
    'Sell Price($)': [18000, 34000, 26100, 40000, 31500,
                      29400, 32000, 19300, 12000,
                      22000, 20000, 21000, 33000],
    'Age(yrs)': [6, 3, 5, 2, 4,
                 5, 5, 6, 8,
                 6, 7, 7, 5]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
df_encoded = pd.get_dummies(df, columns=['Car Model'])

# if I want to drop one dummy column
# df_encoded = pd.get_dummies(df, columns=['Car Model'], drop_first=True)

# Apply binary encoding on 'Car Model'
# encoder = ce.BinaryEncoder(cols=['Car Model'])
# df_encoded = encoder.fit_transform(df)

# %%
print(df_encoded)
# Out:
#     Mileage  Sell Price($)  Age(yrs)  Car Model_Audi A5  Car Model_BMW X5  \
# 0     69000          18000         6              False              True
# 1     35000          34000         3              False              True
# 2     57000          26100         5              False              True
# 3     22500          40000         2              False              True
# 4     46000          31500         4              False              True
# 5     59000          29400         5               True             False
# 6     52000          32000         5               True             False
# 7     72000          19300         6               True             False
# 8     91000          12000         8               True             False
# 9     67000          22000         6              False             False
# 10    83000          20000         7              False             False
# 11    79000          21000         7              False             False
# ...
